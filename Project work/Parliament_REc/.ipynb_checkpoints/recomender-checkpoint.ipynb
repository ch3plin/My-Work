# %%
import pandas as pd 
import numpy as np
df = pd.read_csv("my_data_q.csv")
df.head()
# Out:
#    quesNo                                           subjects  lokNo  \
# 0    3008  Toll Plazas in Dharmapuri, Tamil Nadu         ...     18
# 1    2960           Programmes to improve Connectivity/Lo...     18
# 2    2570  Schemes to promote Skill Development among Far...     18
# 3    2401  Contribution of States in Tourism Industry    ...     18
# 4    2226           Pharmacovigilance System for AYUSH Drugs     18
#
#                                    member                         ministry  \
# 0                             Shri Mani A      ROAD TRANSPORT AND HIGHWAYS
# 1                             Shri Mani A                         RAILWAYS
# 2                             Shri Mani A  AGRICULTURE AND FARMERS WELFARE
# 3                             Shri Mani A                          TOURISM
# 4  Shri E T Mohammed Basheer, Shri Mani A                            AYUSH
#
#         type        date  sessionNo  supplementaryType  year
# ...

# %%
texts = df["subjects"].fillna("").tolist()

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
import faiss

embeddings = model.encode(
    texts,
    show_progress_bar=True
)

embeddings = np.array(
    embeddings,
    dtype="float32"
)

dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(embeddings)
# Out:
# Batches:   0%|          | 0/1165 [00:00<?, ?it/s]

# %%
def recommend(question, k=5):

    vector = model.encode([question]).astype("float32")

    distances, indices = index.search(vector, k)

    return df.iloc[
        indices[0]
    ][[
        "subjects",
        "ministry",
        "member"
    ]]

# %%
recommend("solar energy")
# Out:
#                         subjects                  ministry  \
# 4180   Promotion of Solar Energy  NEW AND RENEWABLE ENERGY
# 27428  Promotion of Solar Energy  NEW AND RENEWABLE ENERGY
# 23327  Promotion of Solar Energy  NEW AND RENEWABLE ENERGY
# 3741          Solar Energy Usage  NEW AND RENEWABLE ENERGY
# 17223         Solar Energy Usage  NEW AND RENEWABLE ENERGY
#
#                                                   member
# 4180   Dr. Vinod Kumar Bind, Shri Pratap Chandra Sarangi
# 27428  Dr. Vinod Kumar Bind, Shri Pratap Chandra Sarangi
# 23327                                    Shri Rajeev Rai
# 3741      Shri Harish Chandra Meena, Shri Sukhdeo Bhagat
# 17223     Shri Harish Chandra Meena, Shri Sukhdeo Bhagat

# %%
def recommend_by_id(row_number):

    query = df.iloc[row_number]["ministry"]

    vector = model.encode([query]).astype("float32")

    distances, indices = index.search(vector,6)

    return df.iloc[
        indices[0][1:]
    ]

# %%
recommend_by_id(100)
# Out:
#        quesNo                                           subjects  lokNo  \
# 1784     2382  External Debt                                 ...     18
# 22394    3140                               Diplomatic Relations     18
# 1607      160                            Country's External Debt     18
# 23957    4771              Relations with Neighbouring Countries     18
# 24607    4085                                   Corruption Cases     18
#
#                           member          ministry       type        date  \
# 1784   Smt. Harsimrat Kaur Badal           FINANCE  UNSTARRED  2025-08-04
# 22394     Shri N K Premachandran  EXTERNAL AFFAIRS  UNSTARRED  2024-08-09
# 1607      Shri Manickam Tagore B           FINANCE  UNSTARRED  2024-07-22
# 23957              Shri Amra Ram  EXTERNAL AFFAIRS  UNSTARRED  2025-03-28
# 24607         Shri Rajesh Ranjan           FINANCE  UNSTARRED  2025-08-18
#
#        sessionNo  supplementaryType  year
# 1784           5              False  2025
# ...

# %%
def search(query, k=5):
    query_vector = model.encode([query]).astype("float32")

    distances, indices = index.search(query_vector, k)

    results = df.iloc[indices[0]][
        ["subjects", "ministry", "member"]
    ].copy()

    results["distance"] = distances[0]

    return results

# %%
results = search("solar energy subsidy")

results
# Out:
#                         subjects                  ministry  \
# 4180   Promotion of Solar Energy  NEW AND RENEWABLE ENERGY
# 23327  Promotion of Solar Energy  NEW AND RENEWABLE ENERGY
# 27428  Promotion of Solar Energy  NEW AND RENEWABLE ENERGY
# 1747         Solar Energy Policy  NEW AND RENEWABLE ENERGY
# 20748        Solar Energy Policy  NEW AND RENEWABLE ENERGY
#
#                                                   member  distance
# 4180   Dr. Vinod Kumar Bind, Shri Pratap Chandra Sarangi  0.310962
# 23327                                    Shri Rajeev Rai  0.310962
# 27428  Dr. Vinod Kumar Bind, Shri Pratap Chandra Sarangi  0.310962
# 1747   Shri Patel Umeshbhai Babubhai, Shri Gajendra  ...  0.328624
# 20748  Shri Patel Umeshbhai Babubhai, Shri Gajendra  ...  0.328624

# %%
df[df["ministry"].str.contains("HEALTH", case=False, na=False)].sample(10)
# Out:
#        quesNo                                           subjects  lokNo  \
# 7334     2046     Ayushman Empaneled Hospitals in Andhra Pradesh     18
# 5626     4318      Ambulances under the National Health Mission      18
# 33041    3241              National Polio Surveillance Programme     18
# 65       3055   National Urban Health Mission                ...     18
# 8565     2015                  Cases of Antimicrobial Resistance     18
# 3104      173  Coverage of Transgender Beneficiaries under  A...     18
# 7887      697  Increase of MBBS Seats in Medical College     ...     18
# 25886    1897                               Vaccines to Children     18
# 5749     2083                       National Midwifery Programme     18
# 868      2034   Eradication of Chronic Endemic Diseases              18
#
#                                                   member  \
# 7334                    Shri Lavu Sri Krishna Devarayalu
# 5626                                   Ms Iqra Choudhary
# ...
