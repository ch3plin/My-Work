# %%
if __name__ == "__main__":

    query = "Construction of National Highways"

    result = predict_ministry(query)

    print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 if __name__ == "__main__":
#       3     query = "Construction of National Highways"
# ----> 5     result = predict_ministry(query)
#       7     print(result)
#
# NameError: name 'predict_ministry' is not defined
