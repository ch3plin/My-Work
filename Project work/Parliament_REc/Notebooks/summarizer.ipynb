# %%
from transformers import pipeline

# Use "text2text-generation" task instead of "summarization"
# or try "text-generation" depending on your transformers version
#summarizer = pipeline(
 #   "text2text-generation",  # Changed from "summarization" to supported task
  #  model="facebook/bart-large-cnn"


# Alternative approach - you can also try:
summarizer = pipeline("text-generation", model="facebook/bart-large-cnn")

# Or update your transformers library first:
# !pip install --upgrade transformers
# Then use the original "summarization" task which should work with newer versions
# Out:
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# [transformers] Please make sure the generation config includes `forced_bos_token_id=0`.
# Loading weights:   0%|          | 0/316 [00:00<?, ?it/s]
# [transformers] BartForCausalLM LOAD REPORT from: facebook/bart-large-cnn
# Key                                                       | Status     |  |
# ----------------------------------------------------------+------------+--+-
# model.encoder.layers.{0...11}.fc1.weight                  | UNEXPECTED |  |
# model.encoder.layers.{0...11}.final_layer_norm.weight     | UNEXPECTED |  |
# model.encoder.layers.{0...11}.fc2.bias                    | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.q_proj.bias       | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.k_proj.bias       | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.out_proj.bias     | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.k_proj.weight     | UNEXPECTED |  |
# ...

# %%
# !pip install --upgrade transformers

# %%
summary = summarizer(
    long_question
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 summary = summarizer(
# ----> 2     long_question
#       3 )
#
# NameError: name 'long_question' is not defined
