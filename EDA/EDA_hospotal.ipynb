# %%
import pandas as pd

# %%
df_bookings= pd.read_csv('D:/DS/@hmaracollege/source-code/3_project_hospitality_analysis/datasets/fact_bookings.csv')
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
 df_bookings.booking_platform.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_date= pd.read_csv('D:/DS/@hmaracollege/source-code/3_project_hospitality_analysis/datasets/dim_date.csv')
df_hotels= pd.read_csv('D:/DS/@hmaracollege/source-code/3_project_hospitality_analysis/datasets/dim_hotels.csv')
df_rooms= pd.read_csv('D:/DS/@hmaracollege/source-code/3_project_hospitality_analysis/datasets/dim_rooms.csv')
df_agbook= pd.read_csv('D:/DS/@hmaracollege/source-code/3_project_hospitality_analysis/datasets/fact_aggregated_bookings.csv')

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_agbook.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agbook.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %%
value=df_agbook.groupby('property_id')['successful_bookings'].sum()
print(value)
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
value=df_agbook.groupby('property_id')['capacity'].max()
print(value)
# Out:
# property_id
# 16558    22.0
# 16559    41.0
# 16560    34.0
# 16561    24.0
# 16562    43.0
# 16563    41.0
# 17558    50.0
# 17559    39.0
# 17560    45.0
# 17561    36.0
# 17562    30.0
# 17563    44.0
# 17564    40.0
# 18558    30.0
# 18559    44.0
# 18560    40.0
# 18561    40.0
# 18562    38.0
# 18563    29.0
# 19558    40.0
# 19559    41.0
# 19560    38.0
# 19561    45.0
# 19562    30.0
# 19563    45.0
# Name: capacity, dtype: float64

# %%
df_agbook[df_agbook.successful_bookings>df_agbook.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agbook.capacity.max()
# Out:
# 50.0

# %%
df_agbook[df_agbook.capacity==df_agbook.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings=df_bookings[df_bookings.no_guests>=0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
avg,std= df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
avg,std
# Out:
# (np.float64(15378.036937686695), 93040.15493143328)

# %%
higher_limit=avg+3*std
higher_limit
# Out:
# np.float64(294498.50173198653)

# %%
lower_limit=avg-3*std
lower_limit
# Out:
# np.float64(-263742.4278566132)

# %%
 df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings= df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.revenue_generated.describe()
# Out:
# count    134573.000000
# mean      14915.959776
# std        6452.676164
# min        6500.000000
# 25%        9900.000000
# 50%       13500.000000
# 75%       18000.000000
# max       45220.000000
# Name: revenue_generated, dtype: float64

# %%
df_bookings[df_bookings.room_category == 'RT4']
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 47       May012216558RT41        16558     26-04-22      1/5/2022
# 48       May012216558RT42        16558     27-04-22      1/5/2022
# 49       May012216558RT43        16558     29-04-22      1/5/2022
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 138      May012216559RT42        16559    11/4/2022      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 47          3/5/2022        2.0           RT4          logtrip            NaN
# ...

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_bookings.no_guests.unique()
# Out:
# array([2., 4., 1., 3., 6., 5.])

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_agbook.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agbook[df_agbook.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_agbook.capacity.median()
# Out:
# 25.0

# %%
df_agbook.capacity.fillna(df_agbook.capacity.median(),inplace=True)
# Out:
# C:\Users\haank\AppData\Local\Temp\ipykernel_29868\2084009095.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_agbook.capacity.fillna(df_agbook.capacity.median(),inplace=True)

# %%
df_agbook[df_agbook.capacity.isna()]
# Out:
# Empty DataFrame
# Columns: [property_id, check_in_date, room_category, successful_bookings, capacity]
# Index: []

# %%
df_agbook[df_agbook.successful_bookings>df_agbook.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agbook = df_agbook[df_agbook.successful_bookings<=df_agbook.capacity]
df_agbook.shape
# Out:
# (9194, 5)

# %%
df_agbook['oc_per'] = df_agbook.apply(lambda row:row['successful_bookings']/row['capacity'] * 100,axis = 1)

# %%
df_agbook.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#       oc_per
# 0  83.333333
# 1  93.333333
# 2  76.666667
# 4  94.736842
# 5  70.000000

# %%
df_agbook.groupby('room_category')['oc_per'].mean() .round(2)
# Out:
# room_category
# RT1    57.89
# RT2    58.01
# RT3    58.03
# RT4    59.28
# Name: oc_per, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_agbook,df_rooms,left_on='room_category',right_on='room_id')
df.tail()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9189        16563     31-Jul-22           RT4                   13      18.0
# 9190        16559     31-Jul-22           RT4                   13      18.0
# 9191        17558     31-Jul-22           RT4                    3       6.0
# 9192        19563     31-Jul-22           RT4                    3       6.0
# 9193        17561     31-Jul-22           RT4                    3       4.0
#
#          oc_per room_id    room_class
# 9189  72.222222     RT4  Presidential
# 9190  72.222222     RT4  Presidential
# 9191  50.000000     RT4  Presidential
# 9192  50.000000     RT4  Presidential
# 9193  75.000000     RT4  Presidential

# %%
df.groupby('room_class')['oc_per'].mean() .round(2)
# Out:
# room_class
# Elite           58.01
# Premium         58.03
# Presidential    59.28
# Standard        57.89
# Name: oc_per, dtype: float64

# %%
df.drop('room_id',axis=1,inplace=True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#       oc_per room_class
# 0  83.333333   Standard
# 1  93.333333   Standard
# 2  76.666667   Standard
# 3  94.736842   Standard
# 4  70.000000   Standard

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df=pd.merge(df,df_hotels,on='property_id')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#       oc_per room_class  property_name  category       city
# 0  83.333333   Standard  Atliq Exotica    Luxury     Mumbai
# 1  93.333333   Standard      Atliq Bay    Luxury  Bangalore
# 2  76.666667   Standard   Atliq Palace  Business  Bangalore
# 3  94.736842   Standard   Atliq Grands    Luxury      Delhi
# 4  70.000000   Standard     Atliq City  Business     Mumbai

# %%
df.groupby('city')['oc_per'].mean().round(2).plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df = pd.merge(df,df_date,left_on='check_in_date',right_on='date')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
# 4        17558     10-May-22           RT1                   11      19.0
#
#       oc_per room_class property_name  category       city       date  mmm yy  \
# 0  51.724138    Premium  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 1  63.333333   Standard    Atliq City  Business  Hyderabad  10-May-22  May 22
# 2  60.000000   Standard     Atliq Bay    Luxury  Bangalore  10-May-22  May 22
# 3  53.333333   Standard  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 4  57.894737   Standard  Atliq Grands    Luxury     Mumbai  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# ...

# %%
df.day_type.unique()
# Out:
# array(['weekeday', 'weekend'], dtype=object)

# %%
df.groupby('day_type')['oc_per'].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: oc_per, dtype: float64

# %%
df['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june=df[df['mmm yy']=='Jun 22']
df_june.head()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
# 2204        16558     10-Jun-22           RT1                   11      19.0
#
#          oc_per room_class  property_name  category       city       date  \
# 2200  66.666667   Standard  Atliq Exotica    Luxury     Mumbai  10-Jun-22
# 2201  63.333333   Standard      Atliq Bay    Luxury  Bangalore  10-Jun-22
# 2202  56.666667   Standard   Atliq Palace  Business  Bangalore  10-Jun-22
# 2203  47.368421   Standard   Atliq Grands    Luxury     Mumbai  10-Jun-22
# 2204  57.894737   Standard   Atliq Grands    Luxury      Delhi  10-Jun-22
#
#       mmm yy week no  day_type
# ...

# %%
df_june.groupby('city')['oc_per'].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.44
# Name: oc_per, dtype: float64

# %%
df_august = pd.read_csv('D:/DS/@hmaracollege/source-code/3_project_hospitality_analysis/datasets/new_data_august.csv')
df_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
lat_df = pd.concat([df,df_august],ignore_index=True,axis=0)
lat_df.tail()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6499        19563     01-Aug-22           RT1                   23      30.0
# 6500        19558     01-Aug-22           RT1                   30      40.0
# 6501        19560     01-Aug-22           RT1                   20      26.0
# 6502        17561     01-Aug-22           RT1                   18      26.0
# 6503        17564     01-Aug-22           RT1                   10      16.0
#
#       oc_per room_class  property_name  category       city date  mmm yy  \
# 6499     NaN   Standard   Atliq Palace  Business  Bangalore  NaN  Aug-22
# 6500     NaN   Standard   Atliq Grands    Luxury  Bangalore  NaN  Aug-22
# 6501     NaN   Standard     Atliq City  Business  Bangalore  NaN  Aug-22
# 6502     NaN   Standard      Atliq Blu    Luxury     Mumbai  NaN  Aug-22
# 6503     NaN   Standard  Atliq Seasons  Business     Mumbai  NaN  Aug-22
#
#      week no  day_type   occ%
# 6499    W 32  weekeday  76.67
# ...

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_rev = pd.merge(df_bookings,df_hotels,on='property_id')
df_rev.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_rev.groupby('city')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# city
# Mumbai       668569251
# Bangalore    420383550
# Hyderabad    325179310
# Delhi        294404488
# Name: revenue_realized, dtype: int64

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
pd.to_datetime(df_date['date'])
# Out:
# C:\Users\haank\AppData\Local\Temp\ipykernel_29868\3763155004.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df_date['date'])
# 0    2022-05-01
# 1    2022-05-02
# 2    2022-05-03
# 3    2022-05-04
# 4    2022-05-05
#         ...
# 87   2022-07-27
# 88   2022-07-28
# 89   2022-07-29
# 90   2022-07-30
# 91   2022-07-31
# Name: date, Length: 92, dtype: datetime64[ns]
